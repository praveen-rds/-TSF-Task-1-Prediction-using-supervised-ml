# %% [markdown]
# # GRIP - The Sparks Foundation

# %% [markdown]
# ### Task 1: Prediction using Supervised ML
# ##### Author:R.D.S Praveen - GRIPOCT2021

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("http://bit.ly/w-data")

# %%
data.shape
# Out:
# (25, 2)

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
data.plot(kind='scatter',x='Hours',y='Scores')
plt.show()

# %%
data.corr(method='pearson')
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
sns.distplot(data['Hours'])
# Out:
# c:\users\prave\anaconda3\envs\sparks\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Hours', ylabel='Density'>

# %%
sns.distplot(data['Scores'])
# Out:
# c:\users\prave\anaconda3\envs\sparks\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Scores', ylabel='Density'>

# %%
x=data.iloc[:, :-1].values
y=data.iloc[:, 1].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=50)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=model.coef_
c=model.intercept_
plt.scatter(x, y)
plt.plot(x, m*x+c);
plt.show()

# %%
y_pred=model.predict(x_test)

# %%
check=pd.DataFrame({'Original':y_test,'Predicted':y_pred})
check
# Out:
#    Original  Predicted
# 0        95  88.211394
# 1        30  28.718453
# 2        76  69.020122
# 3        35  39.273652
# 4        17  13.365436

# %%
sns.distplot(np.array(y_test-y_pred))
plt.show()
# Out:
# c:\users\prave\anaconda3\envs\sparks\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Q=9.2
A=model.predict([[Q]])
print("If a student studies for 9.5 hours per day he/she will score " , A , "% in the test")
# Out:
# If a student studies for 9.5 hours per day he/she will score  [91.09008426] % in the test
